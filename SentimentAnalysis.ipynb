# %% [markdown]
# <a href="https://colab.research.google.com/github/HarisruthiJK/Research-Paper-Summary-Project-1/blob/main/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob

import pandas as pd
import numpy as np
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install textblob

# Simulated feedback dataset
data = {
    'Candidate_ID': range(1, 11),
    'Feedback': [
        "The process was smooth and easy, thank you!",
        "Very disappointed with the delay in processing.",
        "Staff was helpful and responded quickly.",
        "I had a terrible experience. No one answered my calls.",
        "Happy with the guidance I received.",
        "Service was average, not very responsive.",
        "Great support from the documentation team.",
        "Unsatisfactory experience overall.",
        "The consultants were friendly and knowledgeable.",
        "I’m not satisfied with the way my case was handled."
    ]
}

df = pd.DataFrame(data)
df.head()
# Out:
# ...
#    Candidate_ID                                           Feedback
# 0             1        The process was smooth and easy, thank you!
# 1             2    Very disappointed with the delay in processing.
# 2             3           Staff was helpful and responded quickly.
# 3             4  I had a terrible experience. No one answered m...
# 4             5                Happy with the guidance I received.

# %%
# Apply TextBlob sentiment analysis
def analyze_sentiment(text):
    blob = TextBlob(text)
    polarity = blob.sentiment.polarity  # -1 to 1
    if polarity > 0.1:
        return 'Positive'
    elif polarity < -0.1:
        return 'Negative'
    else:
        return 'Neutral'

df['Sentiment'] = df['Feedback'].apply(analyze_sentiment)
df.head()
# Out:
#    Candidate_ID                                           Feedback Sentiment
# 0             1        The process was smooth and easy, thank you!  Positive
# 1             2    Very disappointed with the delay in processing.  Negative
# 2             3           Staff was helpful and responded quickly.  Positive
# 3             4  I had a terrible experience. No one answered m...  Negative
# 4             5                Happy with the guidance I received.  Positive

# %%
# Plot sentiment distribution
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Sentiment', palette='Set2')
plt.title("Candidate Feedback Sentiment Distribution")
plt.ylabel("Number of Responses")
plt.show()
# Out:
# /tmp/ipython-input-4-3401867128.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Sentiment', palette='Set2')

# %%
# Exporting results to CSV (optional)
df.to_csv("sentiment_feedback_results.csv", index=False)
